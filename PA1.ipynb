# %% [markdown]
# # Computer Programming for Liberal Arts

# %% [markdown]
# ## Version 1

# %% [markdown]
# ## CS-150-01- Computer Prog For Liberal Arts SPR-2023

# %% [markdown]
# ## Getting started with markdown

# %% [markdown]
# >This is our first real day of class

# %% [markdown]
# * Variables and Simple Data Types
# * Introducing lists, tuples
# * if Statements
# * Dictionaries
# * While loops
# * Functions
# * Classes
# * Numpy

# %% [markdown]
# 1. Assignment 1
# 2. Assignment 2
# 3. Assignment 3
# 4. Assignment 4
# 5. Assignment 5
# 6. Assignment 6
# 7. Assignment 7

# %% [markdown]
# **This is a sentence with bold words**

# %% [markdown]
# *This is a sentence with italic words*

# %% [markdown]
# `print("Hello")`

# %% [markdown]
# <a href="https://github.com/JamesonBuie">Jameson's Github Account</a>

# %% [markdown]
# ![RainyRoad](data:image/jpeg;base64,...)
